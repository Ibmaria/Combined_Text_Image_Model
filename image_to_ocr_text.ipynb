# %%
#[1]*10**10 #get more ram quickly

# %%
from google.colab import drive
 
drive.mount('/gdrive')
# the project's folder
# %cd /gdrive/'My Drive'/CDIP Dataset
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/CDIP Dataset

# %%
#I unzip images folder
from zipfile import ZipFile
filename='final.zip'
with ZipFile(filename,'r') as zip:
  zip.extractall()
  print("done")
# Out:
# done

# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading https://files.pythonhosted.org/packages/17/4b/4dbd55388225bb6cd243d21f70e77cb3ce061e241257485936324b8e920f/pytesseract-0.3.6.tar.gz
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from pytesseract) (7.0.0)
# Building wheels for collected packages: pytesseract
#   Building wheel for pytesseract (setup.py) ... done
#   Created wheel for pytesseract: filename=pytesseract-0.3.6-py2.py3-none-any.whl size=13629 sha256=966a25bcfdc8da8ff6129e800b30db60bd29e03eb8e58123fa10aef615e9a99e
#   Stored in directory: /root/.cache/pip/wheels/ee/71/72/b98430261d849ae631e283dfc7ccb456a3fb2ed2205714b63f
# Successfully built pytesseract
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.6

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 11 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 3s (1,624 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 144600 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.00~git2288-10f4998a-2_amd64.deb ...
# Unpacking tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Setting up tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
import argparse
import os
import pytesseract

from builtins import str
from joblib import Parallel, delayed
from PIL import Image
from tqdm import tqdm
from imutils import paths

# %%
pytesseract.pytesseract.tesseract_cmd = (
    r'/usr/bin/tesseract'
)

# %%
ensemble_paths = ['Adver/','email/','handwriten/','invoice/','letter/']
base = '/gdrive/My Drive/CDIP Dataset/cvl/train_data/'

# %%
ensemble_paths = ['Adver/','email/','handwriten/','letter/']
base = '/gdrive/My Drive/CDIP Dataset/cvl/train_data/' #traininig
i=1
for ensemble_path in ensemble_paths:
  imagePaths = list(paths.list_images(base +ensemble_path))
  #print(imagePaths)
  for image_path in imagePaths:
    filename = image_path
    format_ = 'txt'
    image = Image.open(filename)
    basename, ext = os.path.splitext(filename)
    print(basename)
    target = basename + "." + format_
    tess_output = pytesseract.image_to_string(image, lang='eng', config="--psm 3 --oem 1")
    #print(len(tess_output))
    if len(tess_output)<4:
      continue
    with open(target, "w",) as fp:
      fp.write(str(tess_output))
    #print("done image"+ str(i))
    i= i+1
        
  print("fini",ensemble_path)
# Out:
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement10
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement100
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement101
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement103
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement104
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement108
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement109
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement11
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement110
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement111
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement112
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement115
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement116
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement117
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement118
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement119
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement12
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement120
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement121
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement124
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement126
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement127
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement128
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement129
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement13
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement130
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement131
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement132
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement133
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement134
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement135
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement137
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement138
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement139
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement14
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement140
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement141
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement142
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement143
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement144
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement145
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement146
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement147
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement150
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement151
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement152
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement154
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement155
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement156
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement157
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement159
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement160
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement161
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement164
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement166
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement167
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement168
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement17
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement170
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement171
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement172
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement173
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement174
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement176
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement177
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement178
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement179
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement18
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement180
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement182
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement186
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement187
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement188
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement189
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement19
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement190
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement192
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement193
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement194
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement195
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement196
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement198
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement199
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement2
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement20
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement201
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement203
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement204
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement205
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement206
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement208
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement209
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertisement210
# /gdrive/My Drive/CDIP Dataset/cvl/train_data/Adver/advertis
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten13
# 483
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten14
# 307
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten15
# 108
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten2
# 95
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten4
# 288
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten439
# 596
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten440
# 433
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten441
# 248
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten444
# 431
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten445
# 565
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten446
# 115
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten448
# 263
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten449
# 647
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten450
# 48
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten451
# 439
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten452
# 137
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten453
# 148
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten454
# 587
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten455
# 402
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten456
# 288
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten458
# 475
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten459
# 1018
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten461
# 475
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten462
# 256
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten463
# 298
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten464
# 134
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten466
# 80
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten467
# 15
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten468
# 492
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten469
# 579
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten471
# 163
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten472
# 80
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten473
# 495
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten477
# 643
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten478
# 668
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten479
# 60
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten480
# 128
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten481
# 1024
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten482
# 225
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten483
# 215
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten485
# 300
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten486
# 474
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten487
# 280
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten488
# 113
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten489
# 947
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten490
# 409
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten491
# 521
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten492
# 225
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten496
# 62
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten6
# 353
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten7
# 159
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten8
# 138
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/handwriten/handwritten9
# 130
# fini handwriten/
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter450
# 1891
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter451
# 2041
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter452
# 845
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter453
# 1994
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter454
# 1553
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter455
# 1263
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter456
# 2195
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter458
# 2360
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter460
# 1440
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter461
# 480
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter462
# 881
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter463
# 1207
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter464
# 1961
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter465
# 1494
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter466
# 1070
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter468
# 806
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter469
# 1061
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter470
# 864
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter471
# 1460
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter472
# 1682
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter473
# 1459
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter474
# 1403
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter476
# 2806
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter477
# 1441
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter478
# 1242
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter479
# 1735
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter480
# 2497
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter483
# 598
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter484
# 704
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter486
# 658
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter487
# 1430
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter488
# 1300
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter489
# 659
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter490
# 1260
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter491
# 760
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter492
# 991
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter493
# 552
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter494
# 2390
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter496
# 2151
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter497
# 1168
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter498
# 1546
# /gdrive/My Drive/CDIP Dataset/cvl/test_data/letter/letter499
# 1878
# fini letter/

# %%
#check if text file contain empty doc
ensemble_paths = ['Adver','email','handwriten','letter']
dict={}
files_vide=[]

include_extension =['txt']
for label in ensemble_paths:
  base ='/gdrive/My Drive/CDIP Dataset/cvl/test_data/'+label   #train_data
  files = [fn for fn in os.listdir(base) if any(fn.endswith(ext) for ext in include_extension)]
  print(len(files))
  for  file in files:
    #print(file)
    fr = open(base+'/'+file,encoding='utf-8',errors='ignore')
    root = file.split('.')[0]
    #print(root)
    text =fr.read().replace('\n','').split()
    if len(text) < 1:
      files_vide.append(file)
      #os.remove(base+'/'+root+'.tif')
      #os.remove(base+'/'+root+'.txt')
      #i+=1
            
       
        
    
    
print('total Files empty',len(files_vide))
# Out:
# 359
# 406
# 388
# 346
# total Files empty 0

# %%
import string
import re
def remove_characters(tokens):
  pattern = re.compile('[{}]'.format(re.escape(string.punctuation)))
  filtered_tokens = filter(None, [pattern.sub('', token) for token in tokens])
  return filtered_tokens

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
import string
stop_words_list = stopwords.words('english')
punctuation_list=list(string.punctuation)
stop_punc_lists=stop_words_list+punctuation_list
#punctuation_list
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def expand_contractions(text, contraction_mapping):
  contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),flags=re.IGNORECASE|re.DOTALL)
  def expand_match(contraction):
    match = contraction.group(0)
    first_char = match[0]
    expanded_contraction = contraction_mapping.get(match) if contraction_mapping.get(match) else contraction_mapping.get(match.lower())
    expanded_contraction = first_char+expanded_contraction[1:]
    return expanded_contraction
  expanded_text = contractions_pattern.sub(expand_match, text)
  expanded_text = re.sub("'", "", expanded_text)
  return expanded_text

# %%
#remove punctuation in text data files
ensemble_paths = ['Adver','email','handwriten','letter']

files_vide=[]
max_len=[]
include_extension =['txt']
for label in ensemble_paths:
  base ='/gdrive/My Drive/CDIP Dataset/cvl/test_data/'+label
    
    #text files selection
  files = [fn for fn in os.listdir(base) if any(fn.endswith(ext) for ext in include_extension)]
  #print(len(files))
  for  file in files:
    fr = open(base+'/'+file,encoding='utf-8',errors='ignore')
    #filename =base+'/'+file
    #root = filename.split('.')[0]
    #print(filename)
    text =fr.read().replace('\n','')
    #print(len(text))
    #print(len(text))
    #print(file)
    text=text.split()
    tokens=[token for token in text if token not in stop_punc_lists]
    tokens=[token.lower() for token in tokens]
    tokens = [token for token in tokens if (len(token) > 2 and len(token)<14)]
    tokens = [token for token in tokens if not token.isdigit()]
    
    max_len.append(len(tokens))
    tokens =' '.join(tokens)
    
    with open(base+'/'+file, "w") as fp:
      fp.write(str(tokens))

# %%
# %cd /gdrive/'My Drive'/CDIP Dataset/cvl
# Out:
# /gdrive/My Drive/CDIP Dataset/cvl

# %%
from my_feature_selection_algo import *
import numpy as np
import codecs

# %%
#Select features for each label
ensemble_labels = ['Adver','email','handwriten','letter']
dict_labels={}
corpus_each_label={}
#files_vide=[]
max_len=[]
include_extension =['txt']
for label in ensemble_labels:
  dict_labels[label]=[]
  corpus_each_label[label]=[]
  base ='/gdrive/My Drive/CDIP Dataset/cvl/final/'+label
    
  #text files selection
  files = [fn for fn in os.listdir(base) if any(fn.endswith(ext) for ext in include_extension)]
  print(len(files))
  for file in files:
    fr = open(base+'/'+file,encoding='utf-8',errors='ignore')
    text =fr.read().replace('\n','')
    corpus_each_label[label].append(text)
    max_len.append(len(text))
        
    text=text.split()
    dict_labels[label].append(text)
# Out:
# 359
# 406
# 388
# 346

# %%
np.mean(max_len)
# Out:
# 426.40226817878585

# %%
#score each feature in each label corpus
dict_words={}
labels = ['Adver','email','handwriten','letter']
for label in labels:
  pos=label 
  corpus=corpus_each_label[pos]
  corpus = ' '.join(corpus)
  corpus=corpus.split()
  corpus = np.unique(corpus)#get unique word
  negative = list(set([pos]).symmetric_difference(set(labels)))
#print(negative)
  for word_corpus in corpus:
    dict_words[word_corpus]=[]
    tp,fn=document_positive_containing_term(pos,dict_labels,word_corpus)
    fp,tn = document_negative_containing_term(negative,dict_labels,word_corpus)
    pos_sample = tp + fn
    neg_sample = fp + tn

    tpr = tp / pos_sample
    fpr = fp / neg_sample
    #print(tpr)
    #print(fpr)
    # score acc2
    score = abs(tpr -fpr)
    #min_q=min(tpr,fpr)
    #if min_q<=0:
     # min_q=-1
    #score =score/min_q
    #else:
     #   score=score/min_q
        
    #score = score/min(tpr,fpr)
    #pos = tp + fn
    dict_words[word_corpus].append({"tp":tp,
                          "fp":fp,
                          "fn":fn,
                           "tn":tn,
                           "score_acc2":score
                                    
                          })
#sort the dict by acc2 score values
  scores_sorted=sorted(dict_words.items(), key=lambda item: item[1][0]['score_acc2'],reverse=True)
  best_features=[]
  for best in scores_sorted:
    best_features.append(best[0])
  best_features =' '.join(best_features) 
  with open('/gdrive/My Drive/CDIP Dataset/cvl/best_features/'+pos+'/'+pos+'.txt','w') as f:
    f.write(str(best_features))
